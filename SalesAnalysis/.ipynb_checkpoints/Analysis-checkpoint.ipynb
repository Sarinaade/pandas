# %% [markdown]
# # Import Necessary Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# ## Merging the 12 months data

# %%
files = [file for file in os.listdir('./Sales_Data')]
all_months_data = pd.DataFrame()
for file in files:
    df = pd.read_csv('./Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data, df])

all_months_data.to_csv('all_data.csv', index=False)

# %%
all_months_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
# 2   222912     AA Batteries (4-pack)                1       3.84
# 3   222913     AA Batteries (4-pack)                1       3.84
# 4   222914    AAA Batteries (4-pack)                5       2.99
#
#        Order Date                  Purchase Address
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101

# %% [markdown]
# ### Updated DataFrame with all months included in one csv file

# %%
all_data = pd.read_csv('all_data.csv', index_col=0)
all_data.head()
# Out:
#                            Product Quantity Ordered Price Each  \
# Order ID
# 222910    Apple Airpods Headphones                1        150
# 222911               Flatscreen TV                1        300
# 222912       AA Batteries (4-pack)                1       3.84
# 222913       AA Batteries (4-pack)                1       3.84
# 222914      AAA Batteries (4-pack)                5       2.99
#
#               Order Date                  Purchase Address
# Order ID
# 222910    07/26/19 16:51   389 South St, Atlanta, GA 30301
# 222911    07/05/19 08:55     590 4th St, Seattle, WA 98101
# 222912    07/29/19 12:41    861 Hill St, Atlanta, GA 30301
# 222913    07/28/19 10:15   190 Ridge St, Atlanta, GA 30301
# 222914    07/31/19 02:13  824 Forest St, Seattle, WA 98101

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186850 entries, 222910 to 259357
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Product           186305 non-null  object
#  1   Quantity Ordered  186305 non-null  object
#  2   Price Each        186305 non-null  object
#  3   Order Date        186305 non-null  object
#  4   Purchase Address  186305 non-null  object
# dtypes: object(5)
# memory usage: 8.6+ MB

# %% [markdown]
# # Cleaning the data

# %%
# Checking for Nan in dataset
nan_df = all_data[all_data.isna()]
nan_df
# Out:
#          Product Quantity Ordered Price Each Order Date Purchase Address
# Order ID
# 222910       NaN              NaN        NaN        NaN              NaN
# 222911       NaN              NaN        NaN        NaN              NaN
# 222912       NaN              NaN        NaN        NaN              NaN
# 222913       NaN              NaN        NaN        NaN              NaN
# 222914       NaN              NaN        NaN        NaN              NaN
# ...          ...              ...        ...        ...              ...
# 259353       NaN              NaN        NaN        NaN              NaN
# 259354       NaN              NaN        NaN        NaN              NaN
# 259355       NaN              NaN        NaN        NaN              NaN
# 259356       NaN              NaN        NaN        NaN              NaN
# 259357       NaN              NaN        NaN        NaN              NaN
#
# [186850 rows x 5 columns]

# %%
# Removing the Nan values in all elements
all_data = all_data.dropna(how='all')
all_data.isna()      # confirm all Nan's are removed
# Out:
#           Product  Quantity Ordered  Price Each  Order Date  Purchase Address  \
# Order ID
# 222910      False             False       False       False             False
# 222911      False             False       False       False             False
# 222912      False             False       False       False             False
# 222913      False             False       False       False             False
# 222914      False             False       False       False             False
# ...           ...               ...         ...         ...               ...
# 259353      False             False       False       False             False
# 259354      False             False       False       False             False
# 259355      False             False       False       False             False
# 259356      False             False       False       False             False
# 259357      False             False       False       False             False
#
#           Month  Sales
# Order ID
# 222910    False  False
# 222911    False  False
# 222912    False  False
# 222913    False  False
# 222914    False  False
# ...         ...    ...
# 259353    False  False
# 259354    False  False
# 259355    False  False
# 259356    False  False
# 259357    False  False
#
# [185950 rows x 7 columns]

# %%
print(all_data['Month'].unique())
# Out:
# [7 8 4 5 10 11 6 1 2 3 12 9]

# %%
# Find and delete "Or"
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']

# %% [markdown]
# ### Converting columns to correct type

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# # Checking the best month for sales and how much was earned

# %% [markdown]
#  ### 1. Creating months columns

# %%
# Extracting the month
all_data.loc[:, 'Month'] = all_data['Order Date'].str[0:2]

# Converting the Month column to int32
all_data.loc[:, 'Month'] = all_data['Month'].astype('int32')

# Display the first few rows
all_data.head()
# Out:
#                            Product  Quantity Ordered  Price Each  \
# Order ID
# 222910    Apple Airpods Headphones                 1      150.00
# 222911               Flatscreen TV                 1      300.00
# 222912       AA Batteries (4-pack)                 1        3.84
# 222913       AA Batteries (4-pack)                 1        3.84
# 222914      AAA Batteries (4-pack)                 5        2.99
#
#               Order Date                  Purchase Address Month   Sales
# Order ID
# 222910    07/26/19 16:51   389 South St, Atlanta, GA 30301     7  150.00
# 222911    07/05/19 08:55     590 4th St, Seattle, WA 98101     7  300.00
# 222912    07/29/19 12:41    861 Hill St, Atlanta, GA 30301     7    3.84
# 222913    07/28/19 10:15   190 Ridge St, Atlanta, GA 30301     7    3.84
# 222914    07/31/19 02:13  824 Forest St, Seattle, WA 98101     7   14.95

# %% [markdown]
# ### 2. Creating sales column

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
#                            Product  Quantity Ordered  Price Each  \
# Order ID
# 222910    Apple Airpods Headphones                 1      150.00
# 222911               Flatscreen TV                 1      300.00
# 222912       AA Batteries (4-pack)                 1        3.84
# 222913       AA Batteries (4-pack)                 1        3.84
# 222914      AAA Batteries (4-pack)                 5        2.99
#
#               Order Date                  Purchase Address Month   Sales
# Order ID
# 222910    07/26/19 16:51   389 South St, Atlanta, GA 30301     7  150.00
# 222911    07/05/19 08:55     590 4th St, Seattle, WA 98101     7  300.00
# 222912    07/29/19 12:41    861 Hill St, Atlanta, GA 30301     7    3.84
# 222913    07/28/19 10:15   190 Ridge St, Atlanta, GA 30301     7    3.84
# 222914    07/31/19 02:13  824 Forest St, Seattle, WA 98101     7   14.95

# %% [markdown]
# ### Checking the best month for sales

# %%
results = all_data.groupby('Month')[['Quantity Ordered', 'Price Each', 'Sales']].sum()
results
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %% [markdown]
# ### Visualize the monthly sales

# %%
import matplotlib.pyplot as plt

months = range(1, 13)

plt.bar(months, results['Sales'])
plt.xticks(months)
plt.xlabel('Months')
plt.ylabel('Sales (Million) in USD (#)')
plt.show()

# %% [markdown]
# ## Insights from the data

# %% [markdown]
# This shows that Decemeber is the best month in terms of sales with the highest sales
