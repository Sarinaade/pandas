# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import numpy as np
from itertools import combinations
from collections import Counter

# %%
# loadd all file from directory on editor

file_name = [file for file in os.listdir('SalesAnalysis/Sales_Data/')]

mearge_df = pd.DataFrame()

for l in file_name:
    df = pd.read_csv(f'SalesAnalysis/Sales_Data/{l}')
    mearge_df = pd.concat([mearge_df,df])
    

mearge_df.shape
# Out:
# (186850, 6)

# %%
mearge_df.to_csv('merge_data_sales/all_data.csv',index=False)

# %%
df = pd.read_csv('merge_data_sales/all_data.csv')
df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
#  ### clean up the data
# * to clean as you perform operations and get errors. Based on the error, you decide how you should go about cleaning the data

# %%
# find NAN

nan_df = df[df.isna().any(axis=1)]
display(nan_df.head())
nan_df.shape
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 264       NaN     NaN              NaN        NaN        NaN              NaN
# 648       NaN     NaN              NaN        NaN        NaN              NaN
# 680       NaN     NaN              NaN        NaN        NaN              NaN
# 1385      NaN     NaN              NaN        NaN        NaN              NaN
# 1495      NaN     NaN              NaN        NaN        NaN              NaN
# (545, 6)

# %%
 # drop na value

df = df.dropna(how='all')
df.shape
# Out:
# (186305, 6)

# %%
df = df[df['Order ID'] != 'Order ID']

# %%
df.describe()
# Out:
#        Order ID               Product Quantity Ordered Price Each  \
# count    185950                185950           185950     185950
# unique   178437                    19                9         23
# top      160873  USB-C Charging Cable                1      11.95
# freq          5                 21903           168552      21903
#
#             Order Date                        Purchase Address
# count           185950                                  185950
# unique          142395                                  140787
# top     12/15/19 20:16  193 Forest St, San Francisco, CA 94016
# freq                 8                                       9

# %%
df['Order Date'].str.split()[0][0]
# Out:
# '12/30/19'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186495 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
# dtypes: object(6)
# memory usage: 14.0+ MB

# %%
# add month column

df['date'] = pd.to_datetime(df['Order Date'].str.split()[0][0])
# Out:
# /var/folders/gz/c4pp41hd2_lb8vgsrz9drfh40000gn/T/ipykernel_1315/153623288.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['Order Date'].str.split()[0][0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   month             185950 non-null  object
#  7   date              185950 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(7)
# memory usage: 16.8+ MB

# %%
df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address month       date
# 0  136 Church St, New York City, NY 10001    12 2019-12-30
# 1     562 2nd St, New York City, NY 10001    12 2019-12-30
# 2    277 Main St, New York City, NY 10001    12 2019-12-30
# 3     410 6th St, San Francisco, CA 94016    12 2019-12-30
# 4           43 Hill St, Atlanta, GA 30301    12 2019-12-30

# %%
df['month'] = df['Order Date'].str[:2]
# Out:
# /var/folders/gz/c4pp41hd2_lb8vgsrz9drfh40000gn/T/ipykernel_1315/1828455704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['Order Date'].str[:2]

# %%
nan_df = df[df.isna().any(axis=1)]

# %%
df.drop(columns=['date'],inplace=True)

# %%
display(nan_df.head())
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address  \
# 264       NaN     NaN              NaN        NaN        NaN              NaN
# 648       NaN     NaN              NaN        NaN        NaN              NaN
# 680       NaN     NaN              NaN        NaN        NaN              NaN
# 1385      NaN     NaN              NaN        NaN        NaN              NaN
# 1495      NaN     NaN              NaN        NaN        NaN              NaN
#
#      month
# 264    NaN
# 648    NaN
# 680    NaN
# 1385   NaN
# 1495   NaN

# %%
df['month'].unique()
# Out:
# array(['12', '01', '04', '05', '02', '03', '08', '09', '06', '11', '10',
#        '07'], dtype=object)

# %%
df = df.dropna(how='all')
df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address month
# 0  136 Church St, New York City, NY 10001    12
# 1     562 2nd St, New York City, NY 10001    12
# 2    277 Main St, New York City, NY 10001    12
# 3     410 6th St, San Francisco, CA 94016    12
# 4           43 Hill St, Atlanta, GA 30301    12

# %%
df['month'] = df['month'].astype('int32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   month             185950 non-null  int32
#  7   date              185950 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int32(1), object(6)
# memory usage: 16.1+ MB
# /var/folders/gz/c4pp41hd2_lb8vgsrz9drfh40000gn/T/ipykernel_1315/2324829600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['month'].astype('int32')

# %%
# add sales column

df['sales' ] = df['Quantity Ordered'].astype(int) *df['Price Each'].astype(float)
df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address  month       date    sales
# 0  136 Church St, New York City, NY 10001     12 2019-12-30  1700.00
# 1     562 2nd St, New York City, NY 10001     12 2019-12-30   600.00
# 2    277 Main St, New York City, NY 10001     12 2019-12-30    11.95
# 3     410 6th St, San Francisco, CA 94016     12 2019-12-30   149.99
# 4           43 Hill St, Atlanta, GA 30301     12 2019-12-30    11.95

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'] )
df['Price Each']= pd.to_numeric(df['Price Each'] )
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 186849
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   month             185950 non-null  int32
#  7   date              185950 non-null  datetime64[ns]
#  8   sales             185950 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(1), object(4)
# memory usage: 17.5+ MB

# %%
# question 1

monthly_sales = df.groupby('month')[['Quantity Ordered','sales']].sum().reset_index()
monthly_sales.max()
# Out:
# month                    12.00
# Quantity Ordered      28114.00
# sales               4613443.34
# dtype: float64

# %%
sns.barplot(data=monthly_sales,x='month',y='sales',hue='Quantity Ordered',width=0.4)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
# plt.tight_layout(rect=[0,0,0.85,1])

plt.show()

# %%
 # Question 2 : what city had the highest number of sales?

df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  month       date  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12 2019-12-30
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12 2019-12-30
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12 2019-12-30
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12 2019-12-30
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12 2019-12-30
#
#      sales
# 0  1700.00
# 1   600.00
# 2    11.95
# 3   149.99
# 4    11.95

# %%
# add column city

temp_city = df['Purchase Address'].str.split(',')
df['city'] = [i[-1].split()[0] for i in temp_city]

# %%
df['city name'] = df['Purchase Address'].apply(lambda x:x.split(',')[1])

# %%
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  month       date  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12 2019-12-30
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12 2019-12-30
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12 2019-12-30
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12 2019-12-30
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12 2019-12-30
#
#      sales city       city name
# 0  1700.00   NY   New York City
# 1   600.00   NY   New York City
# 2    11.95   NY   New York City
# 3   149.99   CA   San Francisco
# 4    11.95   GA         Atlanta

# %%
df['city'].unique()
# Out:
# array(['NY', 'CA', 'GA', 'OR', 'TX', 'MA', 'ME', 'WA'], dtype=object)

# %%
# sum of 
m_c_s = df.groupby(['city','city name'])[['sales']].sum().reset_index()

# %%
m_c_s
# Out:
#   city       city name       sales
# 0   CA     Los Angeles  5452570.80
# 1   CA   San Francisco  8262203.91
# 2   GA         Atlanta  2795498.58
# 3   MA          Boston  3661642.01
# 4   ME        Portland   449758.27
# 5   NY   New York City  4664317.43
# 6   OR        Portland  1870732.34
# 7   TX          Austin  1819581.75
# 8   TX          Dallas  2767975.40
# 9   WA         Seattle  2747755.48

# %%
m_c_s.max()
# Out:
# city                 WA
# city name       Seattle
# sales        8262203.91
# dtype: object

# %%
sns.barplot(data=m_c_s,x='city',y='sales',hue='city name',width=0.9)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
plt.xticks(rotation=45)
# plt.tight_layout()
plt.show
# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
hourly_date = df.groupby('hour')['minute'].count()
sns.lineplot(x=hourly_date.index,y=hourly_date.values)
plt.grid()

plt.show()
# Out:
# /Users/abhisingh/scipy/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/abhisingh/scipy/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Question 4: What products are most often sold together?

df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  month  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12
#
#         date    sales city       city name  hour  minute
# 0 2019-12-30  1700.00   NY   New York City     0       1
# 1 2019-12-30   600.00   NY   New York City     7       3
# 2 2019-12-30    11.95   NY   New York City    18      21
# 3 2019-12-30   149.99   CA   San Francisco    15      13
# 4 2019-12-30    11.95   GA         Atlanta    12      38

# %%
# df.groupby('Order ID')[['Quantity Ordered','Price Each']].count()
# data frame with create all duplicate

df_m = df[df['Order ID'].duplicated(keep=False)]

df_m['grouped'] = df_m.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
# Out:
# /var/folders/gz/c4pp41hd2_lb8vgsrz9drfh40000gn/T/ipykernel_1315/2997402580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_m['grouped'] = df_m.groupby('Order ID')['Product'].transform(lambda x:','.join(x))

# %%
df_m.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 16   295681                Google Phone                 1      600.00
# 17   295681        USB-C Charging Cable                 1       11.95
# 18   295681  Bose SoundSport Headphones                 1       99.99
# 19   295681            Wired Headphones                 1       11.99
# 36   295698             Vareebadd Phone                 1      400.00
#
#             Order Date                     Purchase Address  month       date  \
# 16 2019-12-25 12:37:00          79 Elm St, Boston, MA 02215     12 2019-12-30
# 17 2019-12-25 12:37:00          79 Elm St, Boston, MA 02215     12 2019-12-30
# 18 2019-12-25 12:37:00          79 Elm St, Boston, MA 02215     12 2019-12-30
# 19 2019-12-25 12:37:00          79 Elm St, Boston, MA 02215     12 2019-12-30
# 36 2019-12-13 14:32:00  175 1st St, New York City, NY 10001     12 2019-12-30
#
#      sales city       city name  hour  minute  \
# 16  600.00   MA          Boston    12      37
# 17   11.95   MA          Boston    12      37
# 18   99.99   MA          Boston    12      37
# 19   11.99   MA          Boston    12      37
# 36  400.00   NY   New York City    14      32
#
#                                               grouped
# 16  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 17  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 18  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 19  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36               Vareebadd Phone,USB-C Charging Cable

# %%
df2 = df_m[['Order ID','grouped']].drop_duplicates()

# %%
df2.head()
# Out:
#    Order ID                                            grouped
# 16   295681  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36   295698               Vareebadd Phone,USB-C Charging Cable
# 42   295703   AA Batteries (4-pack),Bose SoundSport Headphones
# 66   295726                    iPhone,Lightning Charging Cable
# 76   295735   iPhone,Apple Airpods Headphones,Wired Headphones

# %%
count = Counter()

for i in df2['grouped']:
    count.update(Counter(combinations(i.split(','),2)))

for key,value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %%
# What product sold the most? Why do you think it sold the most?
product_group = df.groupby('Product')[['Quantity Ordered']]
quntity_order = product_group.sum()['Quantity Ordered']

# %%
quntity_order
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int32

# %%
sns.barplot(x=quntity_order.index,y=quntity_order.values)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.info()
mean_price = df.groupby('Product')['Price Each'].mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 186849
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int32
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   month             185950 non-null  int32
#  7   date              185950 non-null  datetime64[ns]
#  8   sales             185950 non-null  float64
#  9   city              185950 non-null  object
#  10  city name         185950 non-null  object
#  11  hour              185950 non-null  int32
#  12  minute            185950 non-null  int32
# dtypes: datetime64[ns](2), float64(2), int32(4), object(5)
# memory usage: 21.1+ MB

# %%
mean_price
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %% [markdown]
# # ploat sub ploat
#
# fig,axi = plt.subploats()

# %%
fig,axi = plt.subplots(figsize=(10,10))

plt.title('comparicsion between price and quantity ',color='red',size=20)

ax2 = axi.twinx()

sns.barplot(x=quntity_order.index,y=quntity_order.values,ax=axi,width=0.9)
sns.lineplot(x=mean_price.index,y=mean_price.values,ax=ax2,markers='x')
axi.set_label('Product Name')
axi.set_ylabel('Quantity Order')
ax2.set_ylabel("mean price($)")
axi.set_xticklabels(quntity_order.index,rotation='vertical',size=20,fontsize=12,color='blue')




fig.show()
# Out:
# /Users/abhisingh/scipy/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/abhisingh/scipy/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/gz/c4pp41hd2_lb8vgsrz9drfh40000gn/T/ipykernel_1315/286415723.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  month  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12
#
#         date    sales city       city name  hour  minute
# 0 2019-12-30  1700.00   NY   New York City     0       1
# 1 2019-12-30   600.00   NY   New York City     7       3
# 2 2019-12-30    11.95   NY   New York City    18      21
# 3 2019-12-30   149.99   CA   San Francisco    15      13
# 4 2019-12-30    11.95   GA         Atlanta    12      38
